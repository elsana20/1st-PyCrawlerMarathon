# %% [markdown]
# # API 資料串接 - 以 Dcard API 實作範例
#
# * 了解 Dcard API 使用方式與回傳內容
# * 撰寫程式存取 API 且解析 JSON 格式資料

# %% [markdown]
# ## 作業目標
#
# * 請利用 API: https://www.dcard.tw/_api/forums/pet/posts?popular=true 回答下列問題：
#
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

# %%
# 1. 這個 API 一次會回傳幾筆資料？每一筆資料包含哪些欄位？
import requests,json
r = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=true')
response = r.text

data = json.loads(response)
#json.loads()用於將str型別的資料轉成dict。

print("一次傳回",len(data),"筆資料")
print("每一筆資料包含以下欄位",data[0].keys())
#取dict的key值
# Out:
# 一次傳回 30 筆資料
# 每一筆資料包含以下欄位 dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'gender', 'school', 'department', 'replyTitle', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'withImages', 'withVideos', 'media', 'reportReasonText', 'postAvatar'])

# %%
# 2. 取出每一筆資料的「標題」、「貼文時間」、「留言人數」、「按讚人數」
for i in range(len(data)):
    print("第",i,"筆的標題",(data[i]["title"]))
    print("第",i,"筆的貼文時間",(data[i]["createdAt"]))
    print("第",i,"筆的留言人數",(data[i]["commentCount"]))
    print("第",i,"筆的按讚人數",(data[i]["likeCount"]))
# Out:
# 第 0 筆的標題 我懷疑有工讀生混進我家
# 第 0 筆的貼文時間 2020-01-13T08:42:55.693Z
# 第 0 筆的留言人數 18
# 第 0 筆的按讚人數 538
# 第 1 筆的標題 家有內賊！！！
# 第 1 筆的貼文時間 2020-01-13T02:48:40.653Z
# 第 1 筆的留言人數 6
# 第 1 筆的按讚人數 313
# 第 2 筆的標題 貓貓對我哈氣
# 第 2 筆的貼文時間 2020-01-13T01:32:10.901Z
# 第 2 筆的留言人數 19
# 第 2 筆的按讚人數 304
# 第 3 筆的標題 如果狗狗是司機
# 第 3 筆的貼文時間 2020-01-13T08:21:43.661Z
# 第 3 筆的留言人數 4
# 第 3 筆的按讚人數 191
# 第 4 筆的標題 黑色米克斯也很可愛o(≧v≦)o
# 第 4 筆的貼文時間 2020-01-13T06:45:25.341Z
# 第 4 筆的留言人數 9
# 第 4 筆的按讚人數 118
# 第 5 筆的標題 法柯表情包
# 第 20 筆的貼文時間 2020-01-13T05:54:13.344Z
# 第 20 筆的留言人數 1
# 第 20 筆的按讚人數 13
# 第 21 筆的標題 我們家的肉泥！
# 第 21 筆的貼文時間 2020-01-14T04:05:13.266Z
# 第 21 筆的留言人數 1
# 第 21 筆的按讚人數 12
# 第 22 筆的標題 給送養人的小禮物
# 第 22 筆的貼文時間 2020-01-12T19:31:12.995Z
# 第 22 筆的留言人數 6
# 第 22 筆的按讚人數 12
# 第 23 筆的標題 狗界的憂鬱小生 （圖多
# 第 23 筆的貼文時間 2020-01-13T16:47:38.035Z
# 第 23 筆的留言人數 0
# 第 23 筆的按讚人數 11
# 第 24 筆的標題 台中狗狗協尋 已回家
# 第 24 筆的貼文時間 2020-01-13T14:17:18.843Z
# 第 24 筆的留言人數 3
# 第 24 筆的按讚人數 11
# 第 25 筆的標題 甘願一輩子當你們當奴
# 第 25 筆的貼文時間 2020-01-13T03:52:52.886Z
# 第 25 筆的留言人數 0
# 第 25 筆的按讚人數 11
# 第 26 筆的標題 我是眼鏡鼠🐹
# 第 26 筆的貼文時間 2020-01-14T03:02:32.065Z
# 第 26 筆的留言人數 1
# 第 26 筆的按讚人數 10
# 第 27 筆的標題 貓咪送養
# 第 27 筆的貼文時間 2020-01-13T13:04:47.896Z
# 第 27 筆的留言人數 3
# 第 27 筆的按讚人數 10
# 第 28 筆的標題 可愛的浪浪
# 第 28 筆的貼文時間 2020-01-13T10:28:27.836Z
# 第 28 筆的留言人數 6
# 第 28 筆的按讚人數 10
# 第 29 筆的標題 第一次養幼貓
# 第 29 筆的貼文時間 2020-01-13T04:23:41.330Z
# 第 29 筆的留言人數 3
# 第 29 筆的按讚人數 10

# %%
# 3. 計算熱門/非熱門文章的「平均留言人數」與「平均按讚人數」

total_comment=0
total_like=0
count_number=0

for i in range(len(data)):
    total_comment=total_comment+data[i]["commentCount"]
    total_like=total_like+data[i]["likeCount"]
    count_number=count_number+1

print("熱門文章平均留言人數",total_comment/count_number)
print("熱門文章平均按讚人數",total_like/count_number)


import requests,json
f = requests.get('https://www.dcard.tw/_api/forums/pet/posts?popular=false')
response = f.text
#非熱門文章資料

data_f = json.loads(response)
#json.loads()用於將str型別的資料轉成dict。

total_comment=0
total_like=0
count_number=0

for i in range(len(data_f)):
    total_comment=total_comment+data_f[i]["commentCount"]
    total_like=total_like+data_f[i]["likeCount"]
    count_number=count_number+1

print("非熱門文章平均留言人數",total_comment/count_number)
print("非熱門文章平均按讚人數",total_like/count_number)
# Out:
# 熱門文章平均留言人數 4.333333333333333
# 熱門文章平均按讚人數 68.53333333333333
# 非熱門文章平均留言人數 1.9333333333333333
# 非熱門文章平均按讚人數 7.266666666666667
